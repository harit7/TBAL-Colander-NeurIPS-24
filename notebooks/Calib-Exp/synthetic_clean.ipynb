# %%
import sys
from multiprocessing import Process
from os.path import join

sys.path.append('../')
sys.path.append('../../')

from omegaconf import OmegaConf
from src.utils.run_lib import *
from src.utils.conf_utils import * 

calib_val_frac = 0.5

root_dir = '../../'
conf_dir = f'{root_dir}configs/calib-exp/'

method = 'passive_learning'

model_ds_key = 'synthetic_2d_moons'

root_pfx = f'test_runs/{model_ds_key}_calib/'

base_conf                = OmegaConf.load(f'{conf_dir}/{model_ds_key}_base_conf_torch.yaml')
base_conf['output_root'] = join(root_dir, 'outputs', root_pfx)

base_conf['eval'] = 'full'
base_conf['root_pfx'] = root_pfx
base_conf['calib_conf'] = None 


run_train_time = True   
run_post_hoc   = False 

all_outs = []

# %%
base_conf['method'] = method #'passive_learning' # single round
#base_conf['method'] = 'active_labeling'  # multi round
base_conf['training_conf']['weight_decay'] = 0.0
base_conf['training_conf']['learning_rate'] = 0.01
base_conf['training_conf']['max_epochs'] = 200

base_conf['val_pts_query_conf']['max_num_val_pts'] = 500

base_conf['train_pts_query_conf']['max_num_train_pts'] = 50

# %%
def safe_to_numpy(x):
    if(torch.is_tensor(x)):
        return x.numpy()
    else:
        return x

# %%
def augment_conf(conf):
    calib_conf = conf['calib_conf']
    if(calib_conf!=None):
        conf['run_dir']        = join(conf['output_root'], calib_conf['name'])
    else:
        conf['run_dir']        = join(conf['output_root'], "None")
    
    
    if(calib_conf and (calib_conf['type']=='post_hoc')):
        ckpt_file_name = get_model_ckpt_file_name(conf)

        conf.training_conf['save_ckpt'] = True 
        conf.training_conf['train_from_scratch'] = False  
        conf.training_conf['ckpt_save_path'] = join(root_dir, 'ckpt', ckpt_file_name)
        conf.training_conf['ckpt_load_path'] = join(root_dir, 'ckpt', ckpt_file_name)

    if( calib_conf and  (calib_conf['type']=='train_time')):
        for k in  calib_conf.training_conf.keys():
            conf.training_conf[k] = calib_conf.training_conf[k]

        ckpt_file_name = get_model_ckpt_file_name(conf)

        conf.training_conf['ckpt_save_path'] = f'{root_dir}/ckpt/{ckpt_file_name}'

    conf['log_file_path']  = join(conf['run_dir'], conf['method'] + '.log')
    conf['out_file_path']  = join(conf['run_dir'], conf['method'] + '.pkl')
    conf['conf_file_path'] = join(conf['run_dir'], conf['method'] + '.yaml')

    return conf

# %%
data_conf = base_conf['data_conf']

data_conf['train_set_size'] = 10000
data_conf['dimension'] = 2 
data_conf['val_fraction'] = 0.3
data_conf['test_set_size'] = 4000

model_conf = base_conf['model_conf']
model_conf["input_dimension"] = 2 

conf = base_conf 

augment_conf(conf)
# Out:
# {'random_seed': 1, 'device': 'cuda:0', 'lib': 'pytorch', 'data_conf': {'name': 'synth_moon', 'train_set_size': 10000, 'dimension': 2, 'val_fraction': 0.3, 'num_classes': 2, 'test_set_size': 4000, 'random_state': 0}, 'model_conf': {'name': 'dynamic_mlp', 'input_dimension': 2, 'output_dimension': 2, 'layers': [{'type': 'linear', 'dim_factor': 10}, {'type': 'activation', 'act_fun': 'tanh'}, {'type': 'linear', 'dim_factor': 10}, {'type': 'activation', 'act_fun': 'tanh'}, {'type': 'linear', 'dim_factor': 5}, {'type': 'activation', 'act_fun': 'tanh'}], 'num_classes': 2, 'fit_intercept': True, 'lib': 'pytorch'}, 'training_conf': {'loss_function': 'std_cross_entropy', 'optimizer': 'sgd', 'momentum': 0.9, 'weight_decay': 0.0, 'learning_rate': 0.01, 'loss_tolerance': 1e-06, 'max_epochs': 200, 'normalize_weights': False, 'batch_size': 64, 'train_err_tol': -1, 'ckpt_load_path': 'None', 'ckpt_save_path': 'None', 'train_from_scratch': True, 'train_from_ckpt': False}, 'inference_conf': None, 'train_pts_query_conf': {'seed_train_size': 32, 'query_batch_size': 16, 'query_strategy_name': 'margin_random_v2', 'margin_random_v2_constant': 2, 'max_num_train_pts': 50}, 'val_pts_query_conf': {'query_strategy_name': 'random', 'max_num_val_pts': 500}, 'calib_conf': None, 'auto_lbl_conf': {'method_name': 'selective', 'score_type': 'confidence', 'class_wise': 'independent', 'auto_label_err_threshold': 0.01, 'C_1': 0.25, 'ucb': 'sigma'}, 'stopping_criterion': 'max_num_train_pts', 'store_model_weights_in_mem': False, 'output_root': '../../outputs/test_runs/synthetic_2d_moons_calib/', 'eval': 'full', 'root_pfx': 'test_runs/synthetic_2d_moons_calib/', 'method': 'passive_learning', 'run_dir': '../../outputs/test_runs/synthetic_2d_moons_calib/None', 'log_file_path': '../../outputs/test_runs/synthetic_2d_moons_calib/None/passive_learning.log', 'out_file_path': '../../outputs/test_runs/synthetic_2d_moons_calib/None/passive_learning.pkl', 'conf_file_path': '../../outputs/test_runs/synthetic_2d_moons_calib/None/passive_learning.yaml'}

# %%
overwrite = True 

if('calib_conf' in conf and conf['calib_conf'] not in [None, "None"]):
    conf['calib_conf']['device'] = conf['device']

if(not overwrite):
    if(os.path.exists(conf['out_file_path'])):
        print(f"path exists {conf['out_file_path']}")
try:
    os.makedirs(conf['run_dir'])
except OSError:
    pass

ckpt_save_path = conf.training_conf['ckpt_save_path'] 

if(ckpt_save_path) :
    #check if ckpt_save_path directories exist, if not create.
    ckpt_dir_path  = os.path.sep.join( ckpt_save_path.split(os.path.sep)[:-1])

    try:
        os.makedirs(ckpt_dir_path)
    except OSError:
        pass

set_defaults(conf)

conf['inference_conf']['device'] = conf['device']

if('conf_file_path' in conf):
    with open(conf['conf_file_path'],'w') as f:
            OmegaConf.save(config=conf, f=f)

logger = get_logger(conf['log_file_path'],stdout_redirect=True,level=logging.DEBUG)

# %%
def run_conf_2(conf):
    set_seed(conf['random_seed'])
    # get data
    dm = DataManager(conf,logger, lib=conf['model_conf']['lib'])

    logger.info('Loaded dataset {}'.format(conf['data_conf']['name']))
    logger.info(f' std_train_size : {len(dm.ds_std_train)} and  std_val_size: {len(dm.ds_std_val)}')

    pas_learn = PassiveLearning(conf,dm,logger)

    out = pas_learn.run()

    auto_lbl_conf = conf['auto_lbl_conf']

    auto_lbl_conf['method_name']= 'selective' 

    #<<<<<<<<<<<<<<<<<<<<<<<<< BEGIN CALIBRATION BLOCK <<<<<<<<<<<<<<<<<<<<<<<<<
    cur_calibrator = None 
    if( conf['calib_conf'] and conf['calib_conf']['type']=='post_hoc'):
        calib_conf    = conf['calib_conf'] 
        logger.info('========================= Training Post-hoc Calibrator   =========================')
        
        logger.info(f"Calib Conf : {conf['calib_conf']}")

        cur_calibrator  = get_calibrator(pas_learn.cur_clf,calib_conf,logger)

        # randomly split the current available validation points into two parts.
        # one part will be used for training the calibrator and other part for finding 
        # the auto-labeling thresholds.
        dm.select_calib_val_points(calib_frac=calib_conf['calib_val_frac'])
        
        cur_val_ds_c , cur_val_idcs_c    = dm.get_cur_calib_val_ds()
        cur_val_ds_nc , cur_val_idcs_nc    = dm.get_cur_non_calib_val_ds()

        #print(np.histogram(cur_val_ds_c.Y.numpy()))

        values, counts = np.unique(cur_val_ds_c.Y.numpy(), return_counts=True)
        print(values)
        print(counts)

        logger.info(f"Number of validation points for training calibrator : {len(cur_val_idcs_c)}")
        cur_calibrator.fit(cur_val_ds_c,ds_val_nc=cur_val_ds_nc)
    else:
        logger.info('=========================    No Post-hoc Calibration     =========================')
        cur_calibrator = None 

    #>>>>>>>>>>>>>>>>>>>>>>>>>>> END CALIBRATION BLOCK  >>>>>>>>>>>>>>>>>>>>>>>>>>>

    auto_labeler = AutoLabeling(conf,dm,pas_learn.cur_clf,logger,cur_calibrator)
    out = auto_labeler.run()
    counts_sel = dm.get_auto_labeling_counts()


    logger.info(f" Selective Auto-labeling counts: {counts_sel}")

    counts_sel['avg_ece_on_val'] =  out['ECE_on_val'] if 'ECE_on_val' in out else None
    counts_sel['avg_ece_no_calib_on_val'] = out['ECE_on_val_no_calib'] if 'ECE_on_val_no_calib' in out else None
    
    dm.unmark_auto_labeled()

    return pas_learn,cur_calibrator, dm, counts_sel

# %%
pl, calib, dm, counts = run_conf_2(conf)
# Out:
# [01/22/2024 04:13:54 PM : DEBUG : data_manag : ] : (7000, 2)
# [01/22/2024 04:13:54 PM : INFO  : data_manag : ] : Loaded dataset synth_moon
# [01/22/2024 04:13:54 PM : INFO  : data_manag : ] : Std train size: 7000 and Std. Val. Size:3000
# [01/22/2024 04:13:54 PM : INFO  : 1036910527 : ] : Loaded dataset synth_moon
# [01/22/2024 04:13:54 PM : INFO  : 1036910527 : ] :  std_train_size : 7000 and  std_val_size: 3000
# [01/22/2024 04:13:54 PM : DEBUG : passive_le : ] : Querying 32 seed training points
# [01/22/2024 04:13:54 PM : DEBUG : passive_le : ] : Queried 32 seed points for training
# [01/22/2024 04:13:54 PM : DEBUG : passive_le : ] : Validation Data Size :500
# [01/22/2024 04:13:54 PM : DEBUG : passive_le : ] : Querying rest of the training points 18 in single batch
# [01/22/2024 04:13:54 PM : INFO  : passive_le : ] : Labeled data size for training: 50
# [01/22/2024 04:13:54 PM : INFO  : passive_le : ] : Labeled data size for validation: 500
# [01/22/2024 04:13:54 PM : INFO  : model_fact : ] : {'name': 'dynamic_mlp', 'input_dimension': 2, 'output_dimension': 2, 'layers': [{'type': 'linear', 'dim_factor': 10}, {'type': 'activation', 'act_fun': 'tanh'}, {'type': 'linear', 'dim_factor': 10}, {'type': 'activation', 'act_fun': 'tanh'}, {'type': 'linear', 'dim_factor': 5}, {'type': 'activation', 'act_fun': 'tanh'}], 'num_classes': 2, 'fit_intercept': True, 'lib': 'pytorch'}
# [01/22/2024 04:13:54 PM : INFO  : passive_le : ] : --------------- Begin Model Training ------------
# [01/22/2024 04:13:54 PM : INFO  : passive_le : ] : Training conf :{'loss_function': 'std_cross_entropy', 'optimizer': 'sgd', 'momentum': 0.9, 'weight_decay': 0.0, 'learning_rate': 0.01, 'loss_tolerance': 1e-06, 'max_epochs': 200, 'normalize_weights': False, 'batch_size': 64, 'train_err_tol': -1, 'ckpt_load_path': 'None', 'ckpt_save_path': 'None', 'train_from_scratch': True, 'train_from_ckpt': False, 'device': 'cuda:0', 'store_embedding': False, 'save_ckpt': False, 'num_trials': 1}
# [01/22/2024 04:13:54 PM : INFO  : passive_le : ] : Model conf : {'name': 'dynamic_mlp', 'input_dimension': 2, 'output_dimension': 2, 'layers': [{'type': 'linear', 'dim_factor': 10}, {'type': 'activation', 'act_fun': 'tanh'}, {'type': 'linear', 'dim_factor': 10}, {'type': 'activation', 'act_fun': 'tanh'}, {'type': 'linear', 'dim_factor': 5}, {'type': 'activation', 'act_fun': 'tanh'}], 'num_classes': 2, 'fit_intercept': True, 'lib': 'pytorch'}
# [01/22/2024 04:13:54 PM : INFO  : model_fact : ] : {'name': 'dynamic_mlp', 'input_dimension': 2, 'output_dimension': 2, 'layers': [{'type': 'linear', 'dim_factor': 10}, {'type': 'activation', 'act_fun': 'tanh'}, {'type': 'linear', 'dim_factor': 10}, {'type': 'activation', 'act_fun': 'tanh'}, {'type': 'linear', 'dim_factor': 5}, {'type': 'activation', 'act_fun': 'tanh'}], 'num_classes': 2, 'fit_intercept': True, 'lib': 'pytorch'}
# [01/22/2024 04:13:54 PM : DEBUG : model_trai : ] : Training conf : {'loss_function': 'std_cross_entropy', 'optimizer': 'sgd', 'momentum': 0.9, 'weight_decay': 0.0, 'learning_rate': 0.01, 'loss_tolerance': 1e-06, 'max_epochs': 200, 'normalize_weights': False, 'batch_size': 64, 'train_err_tol': -1, 'ckpt_load_path': 'None', 'ckpt_save_path': 'None', 'train_from_scratch': True, 'train_from_ckpt': False, 'device': 'cuda:0', 'store_embedding': False, 'save_ckpt': False, 'num_trials': 1, 'shuffle': True, 'use_lr_schedule': True, 'nesterov': False, 'loss_tol': 1e-06, 'stopping_criterion': 'max_epochs', 'log_val_err': False, 'log_val_ece': False, 'log_train_ece': False, 'log_batch_loss_freq': 20, 'log_val_err_freq': 5, 'log_val_ece_freq': 5, 'verbose_logging': False, 'log_train_ece_freq': 5, 'mixup_alpha': 0, 'num_train_pts': 50}
# [01/22/2024 04:13:54 PM : DEBUG : model_trai : ] : Using loss function : <class 'src.classifiers.torch.losses.common_losses.StdCrossEntropyLoss'>
# [01/22/2024 04:13:54 PM : DEBUG : model_trai : ] : Using stopping criterion max_epochs
# [01/22/2024 04:13:54 PM : DEBUG : model_trai : ] : Train Epoch: 0 [0/50 (0%)]	Loss: 0.704949 	 result: {'loss': 0.6963106393814087}
# [01/22/2024 04:13:54 PM : DEBUG : model_trai : ] : Epoch: 0 Training Error : 0.5600 , Training Loss : 0.0141
# [01/22/2024 04:13:54 PM : INFO  : model_trai : ] : Current Model Validation Accuracy: 0.458
# [01/22/2024 04:13:54 PM : INFO  : model_trai : ] : Best Model Validation Accuracy: 0
# [01/22/2024 04:13:54 PM : DEBUG : model_trai : ] : Epoch:0, A new model with validation accuracy 0.458 has been found!
# [01/22/2024 04:13:54 PM : INFO  : model_trai : ] : Saved current model checkpoint to path : None
# [01/22/2024 04:13:54 PM : DEBUG : model_trai : ] : Train Epoch: 1 [0/50 (0%)]	Loss: 0.703024 	 result: {'loss': 0.6955121755599976}
# [01/22/2024 04:13:54 PM : DEBUG : model_trai : ] :
PM : INFO  : threshold_ : ] : auto-labeling threshold t_i=0.9314069747924805 for class 0
# [01/22/2024 04:14:07 PM : INFO  : threshold_ : ] : auto-labeling threshold t_i=0.8559552431106567 for class 1
# [01/22/2024 04:14:07 PM : INFO  : threshold_ : ] : coverage while threshold estimation : 0.682
# [01/22/2024 04:14:07 PM : INFO  : auto_label : ] : auto-labeling thresholds from val set: [0.931407, 0.85595524]
# [01/22/2024 04:14:07 PM : INFO  : auto_label : ] : Num auto labeled points : 4549
# [01/22/2024 04:14:07 PM : INFO  : auto_label : ] : Num validation pts to remove : 341
# [01/22/2024 04:14:07 PM : INFO  : auto_label : ] : ============================== Done Auto-Labeling ==============================
# [01/22/2024 04:14:07 PM : INFO  : 1036910527 : ] :  Selective Auto-labeling counts: {'auto_labeled_acc': 0.9947241151901517, 'coverage_1': 0.6498571428571429, 'coverage_2': 0}

# %%
from sklearn.inspection import DecisionBoundaryDisplay
import matplotlib as mpl

def get_grid_pts(x_min,x_max, y_min, y_max,step=0.005):
    xx, yy = np.mgrid[x_min:x_max:step, y_min:y_max:step]
    positions = np.vstack([xx.ravel(), yy.ravel()]).T 
    return positions,xx,yy

def visualize_decision_boundary(ax,clf,calibrator,dm,normalize=False):

    X,xx,yy = get_grid_pts(-1.25,2.25,-1,1.5)

    Y = torch.zeros(len(X)).long()
    X = torch.Tensor(X)
    X_ = torch.zeros((len(X),2))

    ds = CustomTensorDataset(X=X,Y=Y)
    if(calibrator):
        inf_out = calibrator.predict(ds,inference_conf=None)
    else:
        inf_out = clf.predict(ds,inference_conf=None)


    X = safe_to_numpy(X)
    Y = safe_to_numpy(Y)
    g = safe_to_numpy(inf_out['confidence'])
    g[np.isnan(g)]=0.0
    
    y_hat = safe_to_numpy(inf_out['labels'])
    idx = np.arange(0,len(g),1)

    cmap_neg = plt.cm.Reds

    neg_idx = idx[ y_hat==0 ]
    #colors_neg = cmap_neg(0.6*g[neg_idx] / g[neg_idx].max())
    
    g_ = g[neg_idx]

    if(normalize):
        g_ = g_ - min(g_)
        g_ = g_/max(g_)
    
    colors_neg = cmap_neg(g_)

    print(np.mean(g[neg_idx]),np.std(g[neg_idx]))

    #ax.scatter(X[neg_idx,0],X[neg_idx,1],s=0.1,c=colors_neg)
    '''
    #idx_ = torch.where((g > 0.45) & (g < 0.55), idx)
    idx_ = idx[(g > 0.48) & (g < 0.52)]

    X_ = X[idx_]
    
    ax.scatter(X_[:,0],X_[:,1],s=0.3)
    '''
    
    cmap_pos = plt.cm.Blues
    pos_idx = idx[ y_hat==1 ]
    
    
    g_ = g[pos_idx]

    if(normalize):
        g_ = g_ - min(g_)
        g_ = g_/max(g_)
    
    colors_pos = cmap_pos(g_)
    
    print(np.mean(g[pos_idx]),np.std(g[pos_idx]))
    G = g.reshape(xx.shape)
    #ax.scatter(X[pos_idx,0],X[pos_idx,1],s=0.1,c=colors_pos)
    cm = plt.cm.Blues
   

    cm = plt.cm.Blues(np.linspace(0,1,20))
    cm = mpl.colors.ListedColormap(cm[0:7,:-1])

    #display = DecisionBoundaryDisplay( xx0=xx, xx1=yy, response=G)
    #display = display.plot(ax=ax, cmap=cm)
    #plt.colorbar(display.ax_.collections[3])
    cs = ax.contourf(xx, yy, G,cmap=cm) 


    X,Y = dm.ds_std_train.X ,  dm.ds_std_train.Y
    idx = np.arange(0,len(X),1)

    pos_idx = idx[ Y==1 ]
    neg_idx = idx[ Y==0 ]
    pos_idx = np.random.choice(pos_idx,500,replace=False)
    neg_idx = np.random.choice(neg_idx,500,replace=False)

    ax.scatter(X[pos_idx,0], X[pos_idx,1], color='blue', s=0.1)
    ax.scatter(X[neg_idx,0], X[neg_idx,1], color='red',  s=0.1)


def visualize_scores_dist(ax, inf_out, clf=None, calibrator=None, ds=None, plot_type={}, normalize=False):
    
    if(inf_out==None):
        if(calibrator):
            inf_out = calibrator.predict(ds,inference_conf=None)
        else:
            inf_out = clf.predict(ds,inference_conf=None)
    
    
    y_hat = safe_to_numpy(inf_out['labels'])
    Y     = safe_to_numpy(inf_out['true_labels'])
    idx = np.arange(0,len(Y),1) 

    correct_idcs   = idx[y_hat==Y]
    incorrect_idcs = idx[y_hat!=Y]

    scores = safe_to_numpy(inf_out['confidence'])
    #sns.histplot(np.clip(scores[correct_idcs],0,1),ax=ax_scores_dist)
    #sns.histplot(np.clip(scores[incorrect_idcs],0,1),ax=ax_scores_dist)
    p =plot_type
    if(normalize):
        scores = scores - min(scores)
        scores = scores/max(scores)
    
    if(plot_type['name']=='hist'):
        
        
        h1, edges1 = np.histogram(scores[correct_idcs],bins=p['num_bins'],density=True, )
        h1 = h1/np.sum(h1)
        h2, edges2 = np.histogram(scores[incorrect_idcs],bins=p['num_bins'],density=True, )
        h2 = h2/np.sum(h2)
        ax.bar(edges1[1:], height=h1, width=0.01,color='blue',label='Correct') #histtype=p['histtype']
        ax.bar(edges2[1:], height=h2, width=0.01,color='red',label='Incorrect')
        ax.set_xlim(-0.1,1.1)
        ax.set_ylim(0,max(max(h1),max(h2)))
        

    elif(plot_type['name']=='kde'):
        sns.kdeplot(np.clip(scores[correct_idcs],0,1),ax=ax, clip=(0,1.05), fill=p['fill'],label='Correct')
        sns.kdeplot(np.clip(scores[incorrect_idcs],0,1),ax=ax, clip=(0,1.05), fill=p['fill'],label='Incorrect')
    ax.legend(loc='upper left')

# %%
def visualize_error_cov(ax, inf_out, clf=None, calibrator=None, ds=None, plot_type={}, normalize=False):
    
    if(inf_out==None):
        if(calibrator):
            inf_out = calibrator.predict(ds,inference_conf=None)
        else:
            inf_out = clf.predict(ds,inference_conf=None)
    

    o = inf_out 
    
    m = len(o['confidence'])
    S = np.zeros((m,4))
    S[:,0] = o['confidence']
    S[:,1] = o['labels'] 
    S[:,2] = o['true_labels']
    S[:,3] = S[:,1]==S[:,2]

    S = S[(-S[:,0]).argsort()]
    
    z = np.cumsum(S[:,3])
    M = np.cumsum(np.ones(m))
    err = (1-(z/M))
    cov = M/m





    color = 'tab:blue'
    l1 = ax.plot(S[:,0], cov, color=color,marker='*',markevery=200, label='Coverage')
    ax.tick_params(axis='y', labelcolor=color)
    ax.set_xlabel('Confidence score')
    
    

    ax.set_ylabel('Coverage', color=color)

    ax2 = ax.twinx()

    color = 'tab:red'
    l2 = ax2.plot(S[:,0],err,color=color, marker='v',markevery=200,label='Auto labeling error')
    

    ax2.tick_params(axis='y', labelcolor=color)
    ax2.set_ylabel('Auto labeling error', color=color)

    # added these three lines
    lns = l1+l2
    labs = [l.get_label() for l in lns]
    ax.legend(lns, labs, loc=0)
    
    return err,cov

# %%
dm.unmark_auto_labeled()

ds_ = dm.get_subset_dataset(dm.get_current_unlabeled_idcs())
print(len(ds_))
inf_out = {}
if(calib):
    inf_out = calib.predict(ds_,inference_conf=None)
else:
    inf_out = pl.cur_clf.predict(ds_,inference_conf=None)
inf_out['true_labels'] = ds_.Y


fig, axs = plt.subplots(1, 4,figsize=(22, 4))

cs = visualize_decision_boundary(axs[0],pl.cur_clf,calibrator=None,dm=dm)
fig.colorbar(cs, ax=axs[0], shrink=0.9)

#visualize_scores_dist(axs[1], inf_out, plot_type={"name":"hist", "num_bins":15})
visualize_scores_dist(axs[1], inf_out, plot_type={"name":"kde","fill":True})

bin_data = compute_calibration(inf_out['true_labels'], inf_out['labels'], inf_out['confidence'], num_bins=10)
reliability_diagram_subplot(axs[2], bin_data, draw_ece=True, draw_bin_importance=False, title="Reliability Diagram", 
                                 xlabel="Confidence", ylabel="Expected Accuracy",disable_labels=False)

#fig.colorbar(cs, ax=axs[0], shrink=0.9)
visualize_error_cov(axs[3], inf_out, normalize=False)
# Out:
# 6950
# 0.89438665 0.1256736
# 0.88354456 0.12548272
# (array([0.        , 0.        , 0.        , ..., 0.1148532 , 0.11498057,
#         0.11510791]),
#  array([1.43884892e-04, 2.87769784e-04, 4.31654676e-04, ...,
#         9.99712230e-01, 9.99856115e-01, 1.00000000e+00]))

# %%
conf['calib_conf'] = OmegaConf.load(f'{conf_dir}/post-hoc/auto_lbl_opt_v0_conf.yaml')

calib_conf = conf['calib_conf']

calib_conf['l1']=1.0 
calib_conf['l2']=1000.0 # 3 or 5
calib_conf['l3']=0.0  #1.0
calib_conf['l4']=0.0
calib_conf['calib_val_frac'] = calib_val_frac 

#calib_conf['features_key']  = 'logits'
#calib_conf['features_key']  = 'pre_logits'
calib_conf['features_key']  = 'logits'

#calib_conf['class_wise'] = 'joint'
calib_conf['class_wise'] = 'independent'
#calib_conf['class_wise'] ="joint_g_independent_t"
model = "two_layer"
#model = "linear" 
calib_conf['num_classes'] = 2 


if(model=="two_layer"):
    model_conf = OmegaConf.load('{}/model_confs/two_layer_net_base_conf.yaml'.format(conf_dir))

    model_conf.layers[0]['dim_factor']=2
    model_conf.layers[1]['act_fun']='tanh'

else:
    model_conf = {} 

model_conf['num_classes'] = 2

calib_conf['model_conf'] = model_conf 


#calib_conf['regularize'] = False  
calib_conf['regularize'] = True 
calib_conf['auto_lbl_conf'] = conf.auto_lbl_conf


#calib_conf['features_key']  = 'logits'

#calib_conf['alpha_1'] = 0.0001 #/1.5
calib_conf['alpha_1'] =0.001 #/1.5

calib_conf['training_conf_g']['batch_size'] = 100  # 64

calib_conf['training_conf_g']['optimizer'] = 'adam'
calib_conf['training_conf_g']['learning_rate'] = 1e-1
calib_conf['training_conf_g']['weight_decay'] =  1.0

calib_conf['training_conf_t']['optimizer'] = 'adam'
calib_conf['training_conf_t']['learning_rate'] = 1e-1
calib_conf['training_conf_t']['weight_decay'] = 1.0


calib_conf['training_conf_g']['max_epochs'] = 1000

# %%
pl2, calib2, dm2, counts = run_conf_2(conf)
# Out:
# [01/22/2024 04:14:40 PM : DEBUG : data_manag : ] : (7000, 2)
# [01/22/2024 04:14:40 PM : INFO  : data_manag : ] : Loaded dataset synth_moon
# [01/22/2024 04:14:40 PM : INFO  : data_manag : ] : Std train size: 7000 and Std. Val. Size:3000
# [01/22/2024 04:14:40 PM : INFO  : 1036910527 : ] : Loaded dataset synth_moon
# [01/22/2024 04:14:40 PM : INFO  : 1036910527 : ] :  std_train_size : 7000 and  std_val_size: 3000
# [01/22/2024 04:14:40 PM : DEBUG : passive_le : ] : Querying 32 seed training points
# [01/22/2024 04:14:40 PM : DEBUG : passive_le : ] : Queried 32 seed points for training
# [01/22/2024 04:14:40 PM : DEBUG : passive_le : ] : Validation Data Size :500
# [01/22/2024 04:14:40 PM : DEBUG : passive_le : ] : Querying rest of the training points 18 in single batch
# [01/22/2024 04:14:40 PM : INFO  : passive_le : ] : Labeled data size for training: 50
# [01/22/2024 04:14:40 PM : INFO  : passive_le : ] : Labeled data size for validation: 500
# [01/22/2024 04:14:40 PM : INFO  : model_fact : ] : {'name': 'dynamic_mlp', 'input_dimension': 2, 'output_dimension': 2, 'layers': [{'type': 'linear', 'dim_factor': 10}, {'type': 'activation', 'act_fun': 'tanh'}, {'type': 'linear', 'dim_factor': 10}, {'type': 'activation', 'act_fun': 'tanh'}, {'type': 'linear', 'dim_factor': 5}, {'type': 'activation', 'act_fun': 'tanh'}], 'num_classes': 2, 'fit_intercept': True, 'lib': 'pytorch'}
# [01/22/2024 04:14:40 PM : INFO  : passive_le : ] : --------------- Begin Model Training ------------
# [01/22/2024 04:14:40 PM : INFO  : passive_le : ] : Training conf :{'loss_function': 'std_cross_entropy', 'optimizer': 'sgd', 'momentum': 0.9, 'weight_decay': 0.0, 'learning_rate': 0.01, 'loss_tolerance': 1e-06, 'max_epochs': 200, 'normalize_weights': False, 'batch_size': 64, 'train_err_tol': -1, 'ckpt_load_path': 'None', 'ckpt_save_path': 'None', 'train_from_scratch': True, 'train_from_ckpt': False, 'device': 'cuda:0', 'store_embedding': False, 'save_ckpt': False, 'num_trials': 1, 'shuffle': True, 'use_lr_schedule': True, 'nesterov': False, 'loss_tol': 1e-06, 'stopping_criterion': 'max_epochs', 'log_val_err': False, 'log_val_ece': False, 'log_train_ece': False, 'log_batch_loss_freq': 20, 'log_val_err_freq': 5, 'log_val_ece_freq': 5, 'verbose_logging': False, 'log_train_ece_freq': 5, 'mixup_alpha': 0, 'num_train_pts': 50}
# [01/22/2024 04:14:40 PM : INFO  : passive_le : ] : Model conf : {'name': 'dynamic_mlp', 'input_dimension': 2, 'output_dimension': 2, 'layers': [{'type': 'linear', 'dim_factor': 10}, {'type': 'activation', 'act_fun': 'tanh'}, {'type': 'linear', 'dim_factor': 10}, {'type': 'activation', 'act_fun': 'tanh'}, {'type': 'linear', 'dim_factor': 5}, {'type': 'activation', 'act_fun': 'tanh'}], 'num_classes': 2, 'fit_intercept': True, 'lib': 'pytorch'}
# [01/22/2024 04:14:40 PM : INFO  : model_fact : ] : {'name': 'dynamic_mlp', 'input_dimension': 2, 'output_dimension': 2, 'layers': [{'type': 'linear', 'dim_factor': 10}, {'type': 'activation', 'act_fun': 'tanh'}, {'type': 'linear', 'dim_factor': 10}, {'type': 'activation', 'act_fun': 'tanh'}, {'type': 'linear', 'dim_factor': 5}, {'type': 'activation', 'act_fun': 'tanh'}], 'num_classes': 2, 'fit_intercept': True, 'lib': 'pytorch'}
# [01/22/2024 04:14:40 PM : DEBUG : model_trai : ] : Training conf : {'loss_function': 'std_cross_entropy', 'optimizer': 'sgd', 'momentum': 0.9, 'weight_decay': 0.0, 'learning_rate': 0.01, 'loss_tolerance': 1e-06, 'max_epochs': 200, 'normalize_weights': False, 'batch_size': 64, 'train_err_tol': -1, 'ckpt_load_path': 'None', 'ckpt_save_path': 'None', 'train_from_scratch': True, 'train_from_ckpt': False, 'device': 'cuda:0', 'store_embedding': False, 'save_ckpt': False, 'num_trials': 1, 'shuffle': True, 'use_lr_schedule': True, 'nesterov': False, 'loss_tol': 1e-06, 'stopping_criterion': 'max_epochs', 'log_val_err': False, 'log_val_ece': False, 'log_train_ece': False, 'log_batch_loss_freq': 20, 'log_val_err_freq': 5, 'log_val_ece_freq': 5, 'verbose_logging': False, 'log_train_ece_freq': 5, 'mixup_alpha': 0, 'num_train_pts': 50}
# [01/22/2024 04:14:40 PM : DEBUG : model_trai : ] : Using loss function : <class 'src.classifiers.torch.losses.common_losses.StdCrossEntropyLoss'>
# [01/22/2024 04:14:40 PM : DEBUG : model_trai : ] : Using stopping criterion max_epochs
# [01/22/2024 04:14:40 PM : DEBUG : model_trai : ] : Train Epoch: 0 [0/50 (0%)]	Loss: 0.704949 	 result: {'loss': 0.6963106393814087}
# [01/22/2024 04:14:40 PM : DEBUG : model_trai : ] : Epoch: 0 Training Error : 0.5600 , Training Loss : 0.0141
# [01/22/2024 04:14:40 PM : INFO  : model_trai : ] : Current Model Validation Accuracy: 0.458
# [01/22/2024 04:14:40 PM : INFO  : model_trai : ] : Best Model Validation Accuracy: 0
# [01/22/2024 04:14:40 PM : DEBUG : model_trai : ] : Epoch:0, A new model with validation accuracy 0.458 has been found!
# [01/22/2024 04:14:40 PM : INFO  : model_trai : ] : Saved current model checkpoint to path : None
# [01/22/2024 04:14:40 PM : DEBUG : model_trai : ] : Train Epoch: 1 [0/50 (0%)]	Loss: 0.703024 	 result: {'loss': 0.6955121755599976}
# [01/22/2024 04:14:40 PM : DEBUG : model_trai : ] : Epoch: 1 Training Error : 0.5600 , Training Loss : 0.0141
# [01/22/2024 04:14:40 PM : INFO  : model_trai : ] : Current Model Validation Accuracy: 0.458
# [01/22/2024 04:14:40 PM : INFO  : model_trai : ] : Best Model Validation Accuracy: 0.458
# [01/22/2024 04:14:40 PM : DEBUG : model_trai : ] : Train Epoch: 2 [0/50 (0%)]	Loss: 0.699390 	 result: {'loss': 0.696420431137085}
# [01/22/2024 04:14:40 PM : DEBUG : model_trai : ] : Epoch: 2 Training Error : 0.5600 , Training Loss : 0.0140
# [01/22/2024 04:14:40 PM : INFO  : model_trai : ] : Current Model Validation Accuracy: 0.458
# [01/22/2024 04:14:40 PM : INFO  : model_trai : ] : Best Model Validation Accuracy: 0.458
# [01/22/2024 04:14:40 PM : DEBUG : model_trai : ] : Train Epoch: 3 [0/50 (0%)]	Loss: 0.694263 	 result: {'loss': 0.6956232190132141}
# [01/22/2024 04:14:40 PM : DEBUG : model_trai : ] : Epoch: 3 Training Error : 0.5600 , Training Loss : 0.0139
# [01/22/2024 04:14:40 PM : INFO  : model_trai : ] : Current Model Validation Accuracy: 0.554
# [01/22/2024 04:14:40 PM : INFO  : model_trai : ] : Best Model Validation Accuracy: 0.458
# [01/22/2024 04:14:40 PM : DEBUG : model_trai : ] : Epoch:3, A new model with validation accuracy 0.554 has been found!
# [01/22/2024 04:14:40 PM : INFO  : model_trai : ] : Saved current model checkpoint to path : None
# [01/22/2024 04:14:40 PM : DEBUG : model_trai : ] : Train Epoch:
# [01/22/2024 04:15:03 PM : DEBUG : auto_label : ] : Epoch: 999 Learning Rate g : 0.09997532801828675
# [01/22/2024 04:15:03 PM : DEBUG : auto_label : ] : Epoch: 999 Loss :83.49971313476563
# [01/22/2024 04:15:03 PM : DEBUG : auto_label : ] : Epoch: 999 Surrogate Coverage : 0.5001237392425537 Surrogate Error: 0.08399978280067444
# [01/22/2024 04:15:03 PM : DEBUG : auto_label : ] : Epoch: 999 At t = 0.5, 999 Coverage : 1.0 	 Error : 0.08366534113883972
# [01/22/2024 04:15:03 PM : DEBUG : auto_label : ] : Epoch: 999 Model Norm  0.006810876075178385
# [01/22/2024 04:15:03 PM : INFO  : auto_label : ] : xxxxxxxxxxxxxxxxxxxxx  Auto-labeling actual remaining unlabeled data  xxxxxxxxxxxxxxxxxxxxx
# [01/22/2024 04:15:03 PM : INFO  : auto_label : ] : ========================= Begin Auto-Labeling selective ==========================
# [01/22/2024 04:15:03 PM : DEBUG : auto_label : ] : Auto Labeling Conf : {'method_name': 'selective', 'score_type': 'confidence', 'class_wise': 'independent', 'auto_label_err_threshold': 0.01, 'C_1': 0.25, 'ucb': 'sigma', 'fast': True}
# [01/22/2024 04:15:03 PM : INFO  : auto_label : ] : Number of unlabeled points : 6950
# [01/22/2024 04:15:03 PM : INFO  : data_manag : ] :  Cur calib ds size : 250
# [01/22/2024 04:15:03 PM : INFO  : auto_label : ] : Using number of validation points : 250
# [01/22/2024 04:15:03 PM : INFO  : auto_label : ] : Using Auto-Labeling Error Threshold = 0.01
# [01/22/2024 04:15:04 PM : DEBUG : auto_label : ] : Expected Calibration Error on Validation set : 0.3622109149694443
# [01/22/2024 04:15:04 PM : DEBUG : auto_label : ] : Expected Calibration Error on Validation set with NO Calibration : 0.054035718441009545
# [01/22/2024 04:15:04 PM : INFO  : auto_label : ] : Determining Thresholds : Class Wise : independent
# [01/22/2024 04:15:04 PM : DEBUG : threshold_ : ] : C_1 = 0.25 UCB = sigma
# [01/22/2024 04:15:04 PM : INFO  : threshold_ : ] : auto-labeling threshold t_i=0.4387228190898895 for class 0
# [01/22/2024 04:15:04 PM : INFO  : threshold_ : ] : auto-labeling threshold t_i=0.49433332681655884 for class 1
# [01/22/2024 04:15:04 PM : INFO  : threshold_ : ] : coverage while threshold estimation : 0.896
# [01/22/2024 04:15:04 PM : INFO  : auto_label : ] : auto-labeling thresholds from val set: [0.43872282, 0.49433333]
# [01/22/2024 04:15:04 PM : INFO  : auto_label : ] : Num auto labeled points : 6112
# [01/22/2024 04:15:04 PM : INFO  : auto_label : ] : Num validation pts to remove : 230
# [01/22/2024 04:15:04 PM : INFO  : auto_label : ] : ============================== Done Auto-Labeling ==============================
# [01/22/2024 04:15:04 PM : INFO  : 1036910527 : ] :  Selective Auto-labeling counts: {'auto_labeled_acc': 1.0, 'coverage_1': 0.8731428571428571, 'coverage_2': 0}

# %%
dm2.unmark_auto_labeled()

ds_ = dm2.get_subset_dataset(dm2.get_current_unlabeled_idcs())

inf_out = {}
if(calib2):
    inf_out = calib2.predict(ds_,inference_conf=None)
else:
    inf_out = pl.cur_clf.predict(ds_,inference_conf=None)
inf_out['true_labels'] = ds_.Y

fig, axs = plt.subplots(1, 4,figsize=(22, 4))

cs = visualize_decision_boundary(axs[0],pl.cur_clf,calibrator=None,dm=dm)
fig.colorbar(cs, ax=axs[0], shrink=0.9)

#visualize_scores_dist(axs[1], inf_out, plot_type={"name":"hist", "num_bins":15})
visualize_scores_dist(axs[1], inf_out, plot_type={"name":"kde","fill":True})

#fig.colorbar(cs, ax=axs[0], shrink=0.9)

bin_data = compute_calibration(inf_out['true_labels'], inf_out['labels'], inf_out['confidence'], num_bins=10)
reliability_diagram_subplot(axs[2], bin_data, draw_ece=True, draw_bin_importance=False, title="Reliability Diagram", 
                                 xlabel="Confidence", ylabel="Expected Accuracy",disable_labels=False)

visualize_error_cov(axs[3], inf_out, normalize=False)
# Out:
# 0.89438665 0.1256736
# 0.88354456 0.12548272
# (array([0.        , 0.        , 0.        , ..., 0.1148532 , 0.11498057,
#         0.11510791]),
#  array([1.43884892e-04, 2.87769784e-04, 4.31654676e-04, ...,
#         9.99712230e-01, 9.99856115e-01, 1.00000000e+00]))

# %%
conf['calib_conf']      = OmegaConf.load(f'{conf_dir}/post-hoc/scaling_binning_conf.yaml')
#conf['calib_conf']      = OmegaConf.load(f'{conf_dir}/post-hoc/scaling_conf.yaml')
#conf['calib_conf']      = OmegaConf.load(f'{conf_dir}/post-hoc/top_lbl_hb_conf.yaml')
#conf['calib_conf']      = OmegaConf.load(f'{conf_dir}/post-hoc/dirichlet_conf.yaml')

calib_conf = conf['calib_conf']
calib_conf['calib_val_frac'] = calib_val_frac

#calib_conf["points_per_bin"] = 25
calib_conf['calib_val_frac'] = 0.5 
calib_conf['training_conf']['learning_rate'] = 0.1
calib_conf['training_conf']['weight_decay'] = 0.001
calib_conf['training_conf']['num_bins'] = 20
calib_conf['training_conf']['max_epochs']=100


pl3, calib3, dm3, counts = run_conf_2(conf)
# Out:
# [01/10/2024 01:27:45 PM : DEBUG : data_manag : ] : (7000, 2)
# [01/10/2024 01:27:45 PM : INFO  : data_manag : ] : Loaded dataset synth_moon
# [01/10/2024 01:27:45 PM : INFO  : data_manag : ] : Std train size: 7000 and Std. Val. Size:3000
# [01/10/2024 01:27:45 PM : INFO  : 1036910527 : ] : Loaded dataset synth_moon
# [01/10/2024 01:27:45 PM : INFO  : 1036910527 : ] :  std_train_size : 7000 and  std_val_size: 3000
# [01/10/2024 01:27:45 PM : DEBUG : passive_le : ] : Querying 32 seed training points
# [01/10/2024 01:27:45 PM : DEBUG : passive_le : ] : Queried 32 seed points for training
# [01/10/2024 01:27:45 PM : DEBUG : passive_le : ] : Validation Data Size :500
# [01/10/2024 01:27:45 PM : DEBUG : passive_le : ] : Querying rest of the training points 18 in single batch
# [01/10/2024 01:27:45 PM : INFO  : passive_le : ] : Labeled data size for training: 50
# [01/10/2024 01:27:45 PM : INFO  : passive_le : ] : Labeled data size for validation: 500
# [01/10/2024 01:27:45 PM : INFO  : model_fact : ] : {'name': 'dynamic_mlp', 'input_dimension': 2, 'output_dimension': 2, 'layers': [{'type': 'linear', 'dim_factor': 10}, {'type': 'activation', 'act_fun': 'tanh'}, {'type': 'linear', 'dim_factor': 10}, {'type': 'activation', 'act_fun': 'tanh'}, {'type': 'linear', 'dim_factor': 5}, {'type': 'activation', 'act_fun': 'tanh'}], 'num_classes': 2, 'fit_intercept': True, 'lib': 'pytorch'}
# [01/10/2024 01:27:45 PM : INFO  : passive_le : ] : --------------- Begin Model Training ------------
# [01/10/2024 01:27:45 PM : INFO  : passive_le : ] : Training conf :{'loss_function': 'std_cross_entropy', 'optimizer': 'sgd', 'momentum': 0.9, 'weight_decay': 0.0, 'learning_rate': 0.01, 'loss_tolerance': 1e-06, 'max_epochs': 200, 'normalize_weights': False, 'batch_size': 64, 'train_err_tol': -1, 'ckpt_load_path': 'None', 'ckpt_save_path': 'None', 'train_from_scratch': True, 'train_from_ckpt': False, 'device': 'cuda:0', 'store_embedding': False, 'save_ckpt': False, 'num_trials': 1, 'shuffle': True, 'use_lr_schedule': True, 'nesterov': False, 'loss_tol': 1e-06, 'stopping_criterion': 'max_epochs', 'log_val_err': False, 'log_val_ece': False, 'log_train_ece': False, 'log_batch_loss_freq': 20, 'log_val_err_freq': 5, 'log_val_ece_freq': 5, 'verbose_logging': False, 'log_train_ece_freq': 5, 'mixup_alpha': 0, 'num_train_pts': 50}
# [01/10/2024 01:27:45 PM : INFO  : passive_le : ] : Model conf : {'name': 'dynamic_mlp', 'input_dimension': 2, 'output_dimension': 2, 'layers': [{'type': 'linear', 'dim_factor': 10}, {'type': 'activation', 'act_fun': 'tanh'}, {'type': 'linear', 'dim_factor': 10}, {'type': 'activation', 'act_fun': 'tanh'}, {'type': 'linear', 'dim_factor': 5}, {'type': 'activation', 'act_fun': 'tanh'}], 'num_classes': 2, 'fit_intercept': True, 'lib': 'pytorch'}
# [01/10/2024 01:27:45 PM : INFO  : model_fact : ] : {'name': 'dynamic_mlp', 'input_dimension': 2, 'output_dimension': 2, 'layers': [{'type': 'linear', 'dim_factor': 10}, {'type': 'activation', 'act_fun': 'tanh'}, {'type': 'linear', 'dim_factor': 10}, {'type': 'activation', 'act_fun': 'tanh'}, {'type': 'linear', 'dim_factor': 5}, {'type': 'activation', 'act_fun': 'tanh'}], 'num_classes': 2, 'fit_intercept': True, 'lib': 'pytorch'}
# [01/10/2024 01:27:45 PM : DEBUG : model_trai : ] : Training conf : {'loss_function': 'std_cross_entropy', 'optimizer': 'sgd', 'momentum': 0.9, 'weight_decay': 0.0, 'learning_rate': 0.01, 'loss_tolerance': 1e-06, 'max_epochs': 200, 'normalize_weights': False, 'batch_size': 64, 'train_err_tol': -1, 'ckpt_load_path': 'None', 'ckpt_save_path': 'None', 'train_from_scratch': True, 'train_from_ckpt': False, 'device': 'cuda:0', 'store_embedding': False, 'save_ckpt': False, 'num_trials': 1, 'shuffle': True, 'use_lr_schedule': True, 'nesterov': False, 'loss_tol': 1e-06, 'stopping_criterion': 'max_epochs', 'log_val_err': False, 'log_val_ece': False, 'log_train_ece': False, 'log_batch_loss_freq': 20, 'log_val_err_freq': 5, 'log_val_ece_freq': 5, 'verbose_logging': False, 'log_train_ece_freq': 5, 'mixup_alpha': 0, 'num_train_pts': 50}
# [01/10/2024 01:27:45 PM : DEBUG : model_trai : ] : Using loss function : <class 'src.classifiers.torch.losses.common_losses.StdCrossEntropyLoss'>
# [01/10/2024 01:27:45 PM : DEBUG : model_trai : ] : Using stopping criterion max_epochs
# [01/10/2024 01:27:45 PM : DEBUG : model_trai : ] : Train Epoch: 0 [0/50 (0%)]	Loss: 0.704949 	 result: {'loss': 0.6963106393814087}
# [01/10/2024 01:27:45 PM : DEBUG : model_trai : ] : Epoch: 0 Training Error : 0.5600 , Training Loss : 0.0141
# [01/10/2024 01:27:45 PM : INFO  : model_trai : ] : Current Model Validation Accuracy: 0.458
# [01/10/2024 01:27:45 PM : INFO  : model_trai : ] : Best Model Validation Accuracy: 0
# [01/10/2024 01:27:45 PM : DEBUG : model_trai : ] : Epoch:0, A new model with validation accuracy 0.458 has been found!
# [01/10/2024 01:27:45 PM : INFO  : model_trai : ] : Saved current model checkpoint to path : None
# [01/10/2024 01:27:45 PM : DEBUG : model_trai : ] : Train Epoch: 1 [0/50 (0%)]	Loss: 0.703024 	 result: {'loss': 0.6955121755599976}
# [01/10/2024 01:27:45 PM : DEBUG : model_trai : ] : Epoch: 1 Training Error : 0.5600 , Training Loss : 0.0141
# [01/10/2024 01:27:45 PM : INFO  : model_trai : ] : Current Model Validation Accuracy: 0.458
# [01/10/2024 01:27:45 PM : INFO  : model_trai : ] : Best Model Validation Accuracy: 0.458
# [01/10/2024 01:27:45 PM : DEBUG : model_trai : ] : Train Epoch: 2 [0/50 (0%)]	Loss: 0.699390 	 result: {'loss': 0.696420431137085}
# [01/10/2024 01:27:45 PM : DEBUG : model_trai : ] : Epoch: 2 Training Error : 0.5600 , Training Loss : 0.0140
# [01/10/2024 01:27:45 PM : INFO  : model_trai : ] : Current Model Validation Accuracy: 0.458
# [01/10/2024 01:27:45 PM : INFO  : model_trai : ] : Best Model Validation Accuracy: 0.458
# [01/10/2024 01:27:45 PM : DEBUG : model_trai : ] : Train Epoch: 3 [0/50 (0%)]	Loss: 0.694263 	 result: {'loss': 0.6956232190132141}
# [01/10/2024 01:27:45 PM : DEBUG : model_trai : ] : Epoch: 3 Training Error : 0.5600 , Training Loss : 0.0139
# [01/10/2024 01:27:45 PM : INFO  : model_trai : ] : Current Model Validation Accuracy: 0.554
# [01/10/2024 01:27:45 PM : INFO  : model_trai : ] : Best Model Validation Accuracy: 0.458
# [01/10/2024 01:27:45 PM : DEBUG : model_trai : ] : Epoch:3, A new model with validation accuracy 0.554 has been found!
# [01/10/2024 01:27:45 PM : INFO  : model_trai : ] : Saved current model checkpoint to path : None
# [01/10/2024 01:27:45 PM : DEBUG : model_trai : ] : Train Epoch: 4 [0/50 (0%)]	Loss: 0.687854 	 result: {'loss': 0.6944255828857422}
# [01/10/2024 01:27:45 PM : DEBUG : model_trai : ] : Epoch: 4 Training Error : 0.4800 , Training Loss : 0.0138
# [01/10/2024 01:27:45 PM : INFO  : model_trai : ] : Current Model Validation Accuracy: 0.73
# [01/10/2024 01:27:45 PM : INFO  : model_trai : ] : Best Model Validation Accuracy: 0.554
# [01/10/2024 01:27:45 PM : DEBUG : model_trai : ] : Epoch:4, A new model with validation accuracy 0.73 has been found!
# [01/10/2024 01:27:45 PM : INFO  : model_trai : ] : Saved current model checkpoint to path : None
# [01/10/2024 01:27:45 PM : DEBUG : model_trai : ] : Train Epoch: 5 [0/50 (0%)]	Loss: 0.680359 	 result: {'loss': 0.6957411766052246}
# [01/10/2024 01:27:45 PM : DEBUG : model_trai : ] : Epoch: 5 Training Error : 0.2800 , Training Loss : 0.0136
# [01/10/2024 01:27:45 PM : INFO  : model_trai : ] : Current Model Validation Accuracy: 0.816
# [01/10/2024 01:27:45 PM : INFO  : model_trai : ] : Best Model Validation Accuracy: 0.73
# [01/10/2024 01:27:45 PM : DEBUG : model_trai : ] : Epoch:5, A new model with validation accuracy 0.816 has been found!
# [01/10/2024 01:27:45 PM : INFO  : model_trai : ] : Saved current model checkpoint to path : None
# [01/10/2024 01:27:45 PM : DEBUG : model_trai : ] : Train Epoch: 6 [0/50 (0%)]	Loss: 0.671956 	 result: {'loss': 0.6927065849304199}
# [01/10/2024 01:27:45 PM : DEBUG : model_trai : ] : Epoch: 6 Training Error : 0.1600 , Training Loss : 0.0134
# [01/10/2024 01:27:45 PM : INFO  : model_trai : ] : Current Model Validation Accuracy: 0.826
# [01/10/2024 01:27:45 PM : INFO  : model_trai : ] : Best Model Validation Accuracy: 0.816
# [01/10/2024 01:27:45 PM : DEBUG : model_trai : ] : Epoch:6, A new model with validation accuracy 0.826 has been found!
# [01/10/2024 01:27:45 PM : INFO  : model_trai : ] : Saved current model checkpoint to path : None
# [01/10/2024 01:27:45 PM : DEBUG : model_trai : ] : Train Epoch: 7 [0/50 (0%)]	Loss: 0.662807 	 result: {'loss': 0.6891177892684937}
# [01/10/2024 01:27:45 PM : DEBUG : model_trai : ] : Epoch: 7 Training Error : 0.1800 , Training Loss : 0.0133
# [01/10/2024 01:27:45 PM : INFO  : model_trai : ] : Current Model Validation Accuracy: 0.82
# [01/10/2024 01:27:45 PM : INFO  : model_trai : ] : Best Model Validation Accuracy: 0.826
# [01/10/2024 01:27:45 PM : DEBUG : model_trai : ] : Train Epoch: 8 [0/50 (0%)]	Loss: 0.653052 	 result: {'loss': 0.68994140625}
# [01/10/2024 01:27:46 PM : DEBUG : model_trai : ] : Epoch: 8 Training Error : 0.1600 , Training Loss : 0.0131
# [01/10/2024 01:27:46 PM : INFO  : model_trai : ] : Current Model Validation Accuracy: 0.81
# [01/10/2024 01:27:46 PM : INFO  : model_trai : ] : Best Model Validation Accuracy: 0.826
# [01/10/2024 01:27:46 PM : DEBUG : model_trai : ] : Train Epoch: 9 [0/50 (0%)]	Loss: 0.642811 	 result: {'loss': 0.6982725262641907}
# [01/10/2024 01:27:46 PM : DEBUG : model_trai : ] : Epoch: 9 Training Error : 0.1600 , Training Loss : 0.0129
# [01/10/2024 01:27:46 PM : INFO  : model_trai : ] : Current Model Validation Accuracy: 0.802
# [01/10/2024 01:27:46 PM : INFO  : model_trai : ] : Best Model Validation Accuracy: 0.826
# [01/10/2024 01:27:46 PM : DEBUG : model_trai : ] : Train Epoch: 10 [0/50 (0%)]	Loss: 0.632182 	 result: {'loss': 0.6908076405525208}
# [01/10/2024 01:27:46 PM : DEBUG : model_trai : ] : Epoch: 10 Training Error : 0.1600 , Training Loss : 0.0126
# [01/10/2024 01:27:46 PM : INFO  : model_trai : ] : Current Model Validation Accuracy: 0.8
# [01/10/2024 01:27:46 PM : INFO  : model_trai : ] : Best Model Validation Accuracy: 0.826
# [01/10/2024 01:27:46 PM : DEBUG : model_trai : ] : Train Epoch: 11 [0/50 (0%)]	Loss: 0.621248 	 result: {'loss': 0.6908146142959595}
# [01/10/2024 01:27:46 PM : DEBUG : model_trai : ] : Epoch: 11 Training Error : 0.1800 , Training Loss : 0.0124
# [01/10/2024 01:27:46 PM : INFO  : model_trai : ] : Current Model Validation Accuracy: 0.8
# [01/10/2024 01:27:46 PM : INFO  : model_trai : ] : Best Model Validation Accuracy: 0.826
# [01/10/2024 01:27:46 PM : DEBUG : model_trai : ] : Train Epoch: 12 [0/50 (0%)]	Loss: 0.610076 	 result: {'loss': 0.7136003375053406}
# [01/10/2024 01:27:46 PM : DEBUG : model_trai : ] : Epoch: 12 Training Error : 0.1800 , Training Loss : 0.0122
# [01/10/2024 01:27:46 PM : INFO  : model_trai : ] : Current Model Validation Accuracy: 0.8
# [01/10/2024 01:27:46 PM : INFO  : model_trai : ] : Best Model Validation Accuracy: 0.826
# [01/10/2024 01:27:46 PM : DEBUG : model_trai : ] : Train Epoch:
PM : INFO  : threshold_ : ] : auto-labeling threshold t_i=0.9561741948127747 for class 0
# [01/10/2024 01:28:14 PM : INFO  : threshold_ : ] : auto-labeling threshold t_i=0.9307888746261597 for class 1
# [01/10/2024 01:28:14 PM : INFO  : threshold_ : ] : coverage while threshold estimation : 0.652
# [01/10/2024 01:28:14 PM : INFO  : auto_label : ] : auto-labeling thresholds from val set: [0.9561742, 0.9307889]
# [01/10/2024 01:28:14 PM : INFO  : auto_label : ] : Num auto labeled points : 4457
# [01/10/2024 01:28:14 PM : INFO  : auto_label : ] : Num validation pts to remove : 166
# [01/10/2024 01:28:14 PM : INFO  : auto_label : ] : ============================== Done Auto-Labeling ==============================
# [01/10/2024 01:28:14 PM : INFO  : 1036910527 : ] :  Selective Auto-labeling counts: {'auto_labeled_acc': 0.997083239847431, 'coverage_1': 0.6367142857142857, 'coverage_2': 0}

# %%
dm3.unmark_auto_labeled()

ds_ = dm3.get_subset_dataset(dm3.get_current_unlabeled_idcs())

inf_out = {}
if(calib3):
    inf_out = calib3.predict(ds_,inference_conf=None)
else:
    inf_out = pl.cur_clf.predict(ds_,inference_conf=None)
inf_out['true_labels'] = ds_.Y

fig, axs = plt.subplots(1, 4,figsize=(22, 4))

cs = visualize_decision_boundary(axs[0],pl.cur_clf,calibrator=None,dm=dm)
fig.colorbar(cs, ax=axs[0], shrink=0.9)

#visualize_scores_dist(axs[1], inf_out, plot_type={"name":"hist", "num_bins":15})
visualize_scores_dist(axs[1], inf_out, plot_type={"name":"kde","fill":True})

#fig.colorbar(cs, ax=axs[0], shrink=0.9)

bin_data = compute_calibration(inf_out['true_labels'], inf_out['labels'], inf_out['confidence'], num_bins=10)
reliability_diagram_subplot(axs[2], bin_data, draw_ece=True, draw_bin_importance=False, title="Reliability Diagram", 
                                 xlabel="Confidence", ylabel="Expected Accuracy",disable_labels=False)

visualize_error_cov(axs[3], inf_out, normalize=False)
# Out:
# 0.89438665 0.1256736
# 0.88354456 0.12548272
# (array([0.        , 0.        , 0.        , ..., 0.11499712, 0.11498057,
#         0.11510791]),
#  array([1.43884892e-04, 2.87769784e-04, 4.31654676e-04, ...,
#         9.99712230e-01, 9.99856115e-01, 1.00000000e+00]))

# %%
def visualize_db2(ax,ax_scores_dist,cur_clf, cur_calibrator, dm, normalize=False):

    def get_grid_pts(x_min,x_max, y_min, y_max,step=0.005):
        xx, yy = np.mgrid[x_min:x_max:step, y_min:y_max:step]

        positions = np.vstack([xx.ravel(), yy.ravel()]).T 
        return positions,xx,yy 

    X,xx,yy = get_grid_pts(-1.25,2.25,-1,1.5)
    print(xx.shape,yy.shape)

    Y = torch.zeros(len(X)).long()
    X = torch.Tensor(X)
    X_ = torch.zeros((len(X),2))

    ds = CustomTensorDataset(X=X,Y=Y)
    if(cur_calibrator):
        inf_out = cur_calibrator.predict(ds,inference_conf={"batch_size":100, "device":conf["device"]})
    else:
        inf_out = cur_clf.predict(ds,inference_conf={"batch_size":100, "device":conf["device"]})


    X = safe_to_numpy(X)
    Y = safe_to_numpy(Y)
    g = safe_to_numpy(inf_out['confidence'])
    g[np.isnan(g)]=0.0

       

    y_hat = safe_to_numpy(inf_out['labels'])
    idx = np.arange(0,len(g),1)

    '''
    #idx_ = torch.where((g > 0.45) & (g < 0.55), idx)
    idx_ = idx[(g > 0.48) & (g < 0.52)]

    X_ = X[idx_]
    
    ax.scatter(X_[:,0],X_[:,1],s=0.3)
    '''

    cmap_neg = plt.cm.Reds

    neg_idx = idx[ y_hat==0 ]
    #colors_neg = cmap_neg(0.6*g[neg_idx] / g[neg_idx].max())
    
    g_ = g[neg_idx]
    print('..',g_.min(), g_.max())
    if(normalize):
        g_ = g_ - min(g_)
        g_ = g_/max(g_)

    print('..',g_.min(), g_.max())
    
    g[neg_idx] = g_
    
    colors_neg = cmap_neg(g_)

    print(np.mean(g[neg_idx]),np.std(g[neg_idx]))

    #ax.scatter(X[neg_idx,0],X[neg_idx,1],s=0.1,c=colors_neg)


    cmap_pos = plt.cm.Blues
    pos_idx = idx[ y_hat==1 ]
    
    
    g_ = g[pos_idx]
    print('..',g_.min(), g_.max())
    if(normalize):
        g_ = g_ - min(g_)
        g_ = g_/max(g_)
    print('..',g_.min(), g_.max())
    colors_pos = cmap_pos(g_)
    g[pos_idx] = g_

    print(np.mean(g[pos_idx]),np.std(g[pos_idx]))

    #ax.scatter(X[pos_idx,0],X[pos_idx,1],s=0.1,c=colors_pos)

    X,Y = dm.ds_std_train.X ,  dm.ds_std_train.Y
    idx = np.arange(0,len(X),1)

    pos_idx = idx[ Y==1 ]
    neg_idx = idx[ Y==0 ]
    pos_idx = np.random.choice(pos_idx,500,replace=False)
    neg_idx = np.random.choice(neg_idx,500,replace=False)

    ax.scatter(X[pos_idx,0], X[pos_idx,1], color='blue', s=0.1)
    ax.scatter(X[neg_idx,0], X[neg_idx,1], color='red',  s=0.1)

    G = np.reshape(g,xx.shape)

    cs = ax.contour(xx, yy, G) 
    return cs

# %%
fig, axs = plt.subplots(2, 2,figsize=(12, 7))



cs1 = visualize_db2(axs[0][0],axs[1][0],pl.cur_clf,calib,dm)

cs2 = visualize_db2(axs[0][1],axs[1][1],pl2.cur_clf,calib2,dm2,normalize=False)
fig.colorbar(cs1, ax=axs[0][0], shrink=0.9)
fig.colorbar(cs2, ax=axs[0][1], shrink=0.9)
# Out:
# (700, 500) (700, 500)
# .. 0.5000012 0.9980069
# .. 0.5000012 0.9980069
# 0.9271098 0.11689159
# .. 0.50001216 0.9993376
# .. 0.50001216 0.9993376
# 0.93875366 0.11320035
# (700, 500) (700, 500)
# .. 0.51972824 0.52886575
# .. 0.51972824 0.52886575
# 0.5231665 0.002564801
# .. 0.46083984 0.4713576
# .. 0.46083984 0.4713576
# 0.46470365 0.0030055095

# %%
def visualize_db3(ax,ax_scores_dist,cur_clf, cur_calibrator, dm, normalize=False):

    def get_grid_pts(x_min,x_max, y_min, y_max,step=0.005):
        xx, yy = np.mgrid[x_min:x_max:step, y_min:y_max:step]

        positions = np.vstack([xx.ravel(), yy.ravel()]).T 
        return positions,xx,yy 

    X,xx,yy = get_grid_pts(-1.25,2.25,-1,1.5)
    print(xx.shape,yy.shape)

    Y = torch.zeros(len(X)).long()
    X = torch.Tensor(X)
    X_ = torch.zeros((len(X),2))

    ds = CustomTensorDataset(X=X,Y=Y)
    if(cur_calibrator):
        inf_out = cur_calibrator.predict(ds,inference_conf={"batch_size":100, "device":conf["device"]})
    else:
        inf_out = cur_clf.predict(ds,inference_conf={"batch_size":100, "device":conf["device"]})


    X = safe_to_numpy(X)
    Y = safe_to_numpy(Y)
    g = safe_to_numpy(inf_out['confidence'])
    g[np.isnan(g)]=0.0

       

    y_hat = safe_to_numpy(inf_out['labels'])
    idx = np.arange(0,len(g),1)


    '''
    #idx_ = torch.where((g > 0.45) & (g < 0.55), idx)
    idx_ = idx[(g > 0.48) & (g < 0.52)]

    X_ = X[idx_]
    
    ax.scatter(X_[:,0],X_[:,1],s=0.3)
    '''

    cmap_correct = plt.cm.Greens

    neg_idx = idx[ y_hat==0 ]
    #colors_neg = cmap_neg(0.6*g[neg_idx] / g[neg_idx].max())
    
    g_ = g[neg_idx]
    if(normalize):
        g_ = g_ - min(g_)
        g_ = g_/max(g_)
    g[neg_idx] = g_
    
    pos_idx = idx[ y_hat==1 ]
    
    g_ = g[pos_idx]
    
    if(normalize):
        g_ = g_ - min(g_)
        g_ = g_/max(g_)
    
    g[pos_idx] = g_


    idx_i = idx[y_hat!=Y]

    cmap_i = plt.cm.Reds
    #colors_i = cmap_i(g[idx_i])
    g_ = g[idx_i]*100
    g_ = g_.astype(int)//20
    print(g_)
    colors_i = cmap_i( g_)

    ax.scatter(X[idx_i,0],X[idx_i,1],s=0.1,c=colors_i)

    idx_c = idx[y_hat==Y]
    cmap_c = plt.cm.Greens
    colors_c = cmap_c(g[idx_c])
    ax.scatter(X[idx_c,0],X[idx_c,1],s=0.1,c=colors_c)

    if(cur_calibrator):
        inf_out = cur_calibrator.predict(dm.ds_std_train,inference_conf={"batch_size":100, "device":conf["device"]})
    else:
        inf_out = cur_clf.predict(dm.ds_std_train,inference_conf={"batch_size":100, "device":conf["device"]})

    X,Y = dm.ds_std_train.X ,  dm.ds_std_train.Y
    idx = np.arange(0,len(X),1)
    y_hat = safe_to_numpy(inf_out['labels'])
    print(y_hat.shape,Y.shape)
    Y = safe_to_numpy(Y)
    
    idx_correct = idx[y_hat==Y]
    idx_incorrect = idx[y_hat!=Y]

    pos_idx = idx[ Y==1 ]
    neg_idx = idx[ Y==0 ]

    print(idx_correct.shape)
    idx_c = np.random.choice(idx_correct,500,replace=False)
    idx_i = np.random.choice(idx_incorrect,500,replace=False)

    ax.scatter(X[idx_c,0], X[idx_c,1], color='blue', s=0.1)
    ax.scatter(X[idx_i,0], X[idx_i,1], color='red',  s=0.1)

# %%
fig, axs = plt.subplots(2, 2,figsize=(12, 7))

visualize_db3(axs[0][0],axs[1][0],pl.cur_clf,calib,dm)

visualize_db3(axs[0][1],axs[1][1],pl2.cur_clf,calib2,dm2,normalize=True)
# Out:
# (700, 500) (700, 500)
# [4 4 4 ... 2 2 2]
# (7000,) torch.Size([7000])
# (6150,)
# (700, 500) (700, 500)
# [0 0 0 ... 4 4 4]
# (7000,) torch.Size([7000])
# (6150,)
