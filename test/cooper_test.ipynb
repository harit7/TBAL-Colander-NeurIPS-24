# %%
import os
from collections import OrderedDict

import numpy as np
import matplotlib.pyplot as plt

import torch
from torchvision.datasets import MNIST
from torch.utils.data import DataLoader, random_split
from torchvision import transforms

import cooper
from copy import deepcopy as copy

# %%
class LogisticRegression(torch.nn.Module):
    def __init__(self, input_dim, output_dim):
        super(LogisticRegression, self).__init__()
        self.input_dim = input_dim
        self.linear = torch.nn.Linear(input_dim, output_dim)

    def forward(self, x):
        x = x.view(-1, self.input_dim)
        outputs = self.linear(x)
        return outputs


class NormConstrainedLogReg(cooper.ConstrainedMinimizationProblem):
    def __init__(self):
        self.criterion = torch.nn.CrossEntropyLoss()
        super().__init__(is_constrained=True)

    def closure(self, model, inputs, targets):

        pred_logits = model.forward(inputs)
        loss = self.criterion(pred_logits, targets)

        # We want each row of W to have norm less than or equal to 1
        # g(W) <= 1  ---> g(W) - 1 <= 0
        ineq_defect = model.linear.weight.norm(dim=1) - 1

        return cooper.CMPState(loss=loss, ineq_defect=ineq_defect, eq_defect=None)

# %%
dataset = MNIST(os.getcwd() + "/data", download=True, transform=transforms.ToTensor())
train_set, val_set = random_split(dataset, [55000, 5000])
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to /home/harit/workspace/TBAL-calib/test/data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:01<00:00, 9712249.31it/s]
# Extracting /home/harit/workspace/TBAL-calib/test/data/MNIST/raw/train-images-idx3-ubyte.gz to /home/harit/workspace/TBAL-calib/test/data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to /home/harit/workspace/TBAL-calib/test/data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 28903768.51it/s]
# Extracting /home/harit/workspace/TBAL-calib/test/data/MNIST/raw/train-labels-idx1-ubyte.gz to /home/harit/workspace/TBAL-calib/test/data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to /home/harit/workspace/TBAL-calib/test/data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 7109416.83it/s]
# Extracting /home/harit/workspace/TBAL-calib/test/data/MNIST/raw/t10k-images-idx3-ubyte.gz to /home/harit/workspace/TBAL-calib/test/data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to /home/harit/workspace/TBAL-calib/test/data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 14642989.06it/s]
# Extracting /home/harit/workspace/TBAL-calib/test/data/MNIST/raw/t10k-labels-idx1-ubyte.gz to /home/harit/workspace/TBAL-calib/test/data/MNIST/raw

# %%
cmp = NormConstrainedLogReg()
formulation = cooper.LagrangianFormulation(cmp)

model = LogisticRegression(784, 10)

# primal_optimizer = cooper.optim.ExtraSGD(model.parameters(), lr=1e-3, momentum=0.9)
# dual_optimizer = cooper.optim.partial_optimizer(cooper.optim.ExtraSGD, lr=5e-3)

primal_optimizer = torch.optim.SGD(model.parameters(), lr=1e-3, momentum=0.9)
dual_optimizer = cooper.optim.partial_optimizer(torch.optim.SGD, lr=5e-3)

coop = cooper.ConstrainedOptimizer(
    formulation=formulation,
    primal_optimizer=primal_optimizer,
    dual_optimizer=dual_optimizer,
)

# %%
iter_num = 0

state_history = OrderedDict()

for epoch in range(3):
    for inputs, targets in DataLoader(train_set, batch_size=64):

        coop.zero_grad()
        lagrangian = formulation.composite_objective(
            cmp.closure, model, inputs, targets
        )
        formulation.custom_backward(lagrangian)
        coop.step(cmp.closure, model, inputs, targets)

        if iter_num % 5 == 0:
            state_history[iter_num] = {
                "cmp": cmp.state,
                "dual": copy(formulation.state()),
            }

        iter_num += 1

# %%
iters, loss_history = zip(
    *[(iter_num, _["cmp"].loss.item()) for (iter_num, _) in state_history.items()]
)
mult_hist = np.stack(
    [_["dual"][0].data.numpy() for (foo, _) in state_history.items()], axis=1
)
defect_hist = np.stack(
    [_["cmp"].ineq_defect.data.numpy() for (foo, _) in state_history.items()], axis=1
)

# %%
plt.plot(iters, mult_hist[0:1, ...].T)
plt.show()

# %%
plt.plot(iters, loss_history)

# %%
total, correct = 0, 0
with torch.no_grad():
    for inputs, targets in DataLoader(val_set, batch_size=64):
        outputs = model.forward(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += targets.size(0)
        correct += (predicted == targets).sum()
accuracy = 100 * correct / total

accuracy
# Out:
# tensor(86.4000)
