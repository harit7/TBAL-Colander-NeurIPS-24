# %%
import sys
sys.path.append('../')
import seaborn as sns 
from multiprocessing import Process
from omegaconf import OmegaConf
from src.utils.run_lib import *
import numpy as np 
from src.core.passive_learning import *
from src.core.auto_labeling import *
from src.datasets import dataset_factory 
from src.datasets.dataset_utils import * 
from src.utils.common_utils import * 
from src.utils.vis_utils import *
import copy 
import random 
from src.datasets.numpy_dataset import * 


root_dir = '../'
conf_dir = f'{root_dir}configs/calib-exp/'

base_conf_file = '{}/mnist_lenet_base_conf.yaml'.format(conf_dir)
conf           = OmegaConf.load(base_conf_file)

training_conf  = OmegaConf.load('{}/training_confs/mixup_conf.yaml'.format(conf_dir))

root_pfx       = 'mnist_lenet_calib-exp-runs'
root_pfx       = f'{root_dir}/outputs/{root_pfx}/'


conf['root_pfx']    = root_pfx

conf.training_conf = training_conf

conf.auto_lbl_conf.C_1 = 0.25
conf.auto_lbl_conf.auto_label_err_threshold=0.05 

logger   = get_logger('../temp/logs/act_lbl_test.log',stdout_redirect=True,level=logging.DEBUG)

# %%
conf['train_pts_query_conf']['seed_train_size']= 10
conf['train_pts_query_conf']['max_num_train_pts']= 50

set_seed(conf['random_seed'])

dm = DataManager(conf,logger,lib=conf['model_conf']['lib'])

print(len(dm.ds_std_train), len(dm.ds_std_val))

pl = PassiveLearning(conf,dm,logger)

out = pl.run()

w = pl.cur_clf.get_weights()
print(torch.norm(w))
test_err = get_test_error(pl.cur_clf,dm.ds_std_test,conf['inference_conf'])
print(test_err)
# Out:
# [09/16/2023 05:09:32 PM : DEBUG : data_manag : ] : torch.Size([42000, 28, 28])
# [09/16/2023 05:09:33 PM : INFO  : data_manag : ] : Loaded dataset mnist
# [09/16/2023 05:09:33 PM : INFO  : data_manag : ] : Std train size: 42000 and Std. Val. Size:18000
# 42000 18000
# [09/16/2023 05:09:33 PM : DEBUG : passive_le : ] : Querying 10 seed training points
# [09/16/2023 05:09:33 PM : DEBUG : passive_le : ] : Queried 10 seed points for training
# [09/16/2023 05:09:33 PM : DEBUG : passive_le : ] : Validation Data Size :5000
# [09/16/2023 05:09:33 PM : DEBUG : passive_le : ] : Querying rest of the training points 40 in single batch
# [09/16/2023 05:09:33 PM : INFO  : passive_le : ] : Labeled data size for training: 50
# [09/16/2023 05:09:33 PM : INFO  : pytorch_cl : ] : {'model_name': 'lenet', 'num_classes': 10, 'fit_intercept': True, 'lib': 'pytorch'}
# [09/16/2023 05:09:33 PM : INFO  : passive_le : ] : --------------- Begin Model Training ------------
# [09/16/2023 05:09:33 PM : INFO  : passive_le : ] : Training conf :{'loss_function': 'std_cross_entropy', 'mixup_alpha': -1, 'optimizer': 'sgd', 'learning_rate': 0.1, 'loss_tolerance': 1e-06, 'max_epochs': 50, 'normalize_weights': False, 'batch_size': 32, 'ckpt_load_path': 'None', 'ckpt_save_path': 'None', 'train_from_scratch': True, 'train_from_ckpt': False, 'use_lr_schedule': True, 'shuffle': False, 'device': 'cuda:0', 'store_embedding': False, 'save_ckpt': False, 'num_trials': 1}
# [09/16/2023 05:09:33 PM : INFO  : passive_le : ] : Model conf : {'model_name': 'lenet', 'num_classes': 10, 'fit_intercept': True, 'lib': 'pytorch'}
# [09/16/2023 05:09:33 PM : INFO  : pytorch_cl : ] : {'model_name': 'lenet', 'num_classes': 10, 'fit_intercept': True, 'lib': 'pytorch'}
# [09/16/2023 05:09:33 PM : DEBUG : model_trai : ] : Training conf : {'loss_function': 'std_cross_entropy', 'mixup_alpha': -1, 'optimizer': 'sgd', 'learning_rate': 0.1, 'loss_tolerance': 1e-06, 'max_epochs': 50, 'normalize_weights': False, 'batch_size': 32, 'ckpt_load_path': 'None', 'ckpt_save_path': 'None', 'train_from_scratch': True, 'train_from_ckpt': False, 'use_lr_schedule': True, 'shuffle': False, 'device': 'cuda:0', 'store_embedding': False, 'save_ckpt': False, 'num_trials': 1, 'weight_decay': 0.0001, 'momentum': 0.9, 'loss_tol': 1e-06, 'max_max_epochs': 10000, 'stopping_criterion': 'max_epochs', 'log_val_err': False, 'log_val_ece': False, 'log_train_ece': False, 'train_err_tol': 0.001, 'log_batch_loss_freq': 20, 'log_val_err_freq': 5, 'log_val_ece_freq': 5, 'verbose_logging': False, 'log_train_ece_freq': 5, 'nesterov': False, 'num_train_pts': 50}
# [09/16/2023 05:09:33 PM : DEBUG : model_trai : ] : Using loss function : <class 'models.torch.losses.common_losses.StdCrossEntropyLoss'>
# [09/16/2023 05:09:33 PM : DEBUG : model_trai : ] : Using stopping criterion max_epochs
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /home/reid/projects/TBAL/experiments/Calib-Exp/Test/test_mixup.ipynb Cell 2 line 1
#       <a href='vscode-notebook-cell:/home/reid/projects/TBAL/experiments/Calib-Exp/Test/test_mixup.ipynb#W1sZmlsZQ%3D%3D?line=7'>8</a> print(len(dm.ds_std_train), len(dm.ds_std_val))
#      <a href='vscode-notebook-cell:/home/reid/projects/TBAL/experiments/Calib-Exp/Test/test_mixup.ipynb#W1sZmlsZQ%3D%3D?line=9'>10</a> pl = PassiveLearning(conf,dm,logger)
# ---> <a href='vscode-notebook-cell:/home/reid/projects/TBAL/experiments/Calib-Exp/Test/test_mixup.ipynb#W1sZmlsZQ%3D%3D?line=11'>12</a> out = pl.run()
#      <a href='vscode-notebook-cell:/home/reid/projects/TBAL/experiments/Calib-Exp/Test/test_mixup.ipynb#W1sZmlsZQ%3D%3D?line=13'>14</a> w = pl.cur_clf.get_weights()
#      <a href='vscode-notebook-cell:/home/reid/projects/TBAL/experiments/Calib-Exp/Test/test_mixup.ipynb#W1sZmlsZQ%3D%3D?line=14'>15</a> print(torch.norm(w))
#
# File ~/projects/TBAL/experiments/Calib-Exp/Test/../../../core/passive_learning.py:109, in PassiveLearning.run(self)
#     106     logger.info('Training conf :{}'.format(train_conf))
#     107     logger.info('Model conf : {}'.format(model_conf))
# --> 109     self.cur_clf = train_model(cur_train_ds, model_conf, train_conf,
#     110                                conf.inference_conf,logger,cur_val_ds = cur_val_ds)
#     112     logger.info('--------------- End Model Training ------------')
#     115 if(train_conf['save_ckpt'] and train_conf['ckpt_save_path'] is not None):
#
# File ~/projects/TBAL/experiments/Calib-Exp/Test/../../../core/model_utils.py:20, in train_model(train_dataset, model_conf, training_conf, infernce_conf, logger, cur_val_ds)
#      17 S = training_conf['num_trials']
#      18 #if(S==1):
# ---> 20 clf.fit(train_dataset, training_conf,cur_val_ds)
#      22 if(S>1):
#      23     min_train_err = 1.0
#
# File ~/projects/TBAL/experiments/Calib-Exp/Test/../../../models/torch/pytorch_clf.py:91, in PyTorchClassifier.fit(self, dataset, training_conf, val_set)
#      89 elif(method==None or method=="vanila"):
#      90     model_training = ModelTraining(self.logger)
# ---> 91     out = model_training.train(self.model,dataset,training_conf,val_set=val_set)
#      92 return out
#
# File ~/projects/TBAL/experiments/Calib-Exp/Test/../../../models/torch/model_training.py:219, in ModelTraining.train(self, model, dataset, train_params, val_set)
#     216     logger.debug('Training Epoch {} Begins '.format(epoch))
#     217     logger.debug('Epoch:{} Using learning rate : {}'.format(epoch,lr))
# --> 219 epoch_loss, training_err = self.train_one_epoch(model,train_data_loader,train_params,epoch_state)
#     221 logger.debug(f'Epoch: {epoch} Training Error : {training_err:.4f} , Training Loss : {epoch_loss:.4f}')
#     223 stop = False
#
# File ~/projects/TBAL/experiments/Calib-Exp/Test/../../../models/torch/model_training.py:94, in ModelTraining.train_one_epoch(self, model, train_data_loader, train_params, epoch_state)
#      91 log_batch_loss_freq = train_params['log_batch_loss_freq']
#      93 model.train()
# ---> 94 model = model.to(device)
#      96 y_hat = []
#      97 y_true = []
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1145, in Module.to(self, *args, **kwargs)
#    1141         return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1142                     non_blocking, memory_format=convert_to_format)
#    1143     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
# -> 1145 return self._apply(convert)
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:797, in Module._apply(self, fn)
#     795 def _apply(self, fn):
#     796     for module in self.children():
# --> 797         module._apply(fn)
#     799     def compute_should_use_set_data(tensor, tensor_applied):
#     800         if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     801             # If the new tensor has compatible tensor type as the existing tensor,
#     802             # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     807             # global flag to let the user control whether they want the future
#     808             # behavior of overwriting the existing tensor or not.
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:797, in Module._apply(self, fn)
#     795 def _apply(self, fn):
#     796     for module in self.children():
# --> 797         module._apply(fn)
#     799     def compute_should_use_set_data(tensor, tensor_applied):
#     800         if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     801             # If the new tensor has compatible tensor type as the existing tensor,
#     802             # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     807             # global flag to let the user control whether they want the future
#     808             # behavior of overwriting the existing tensor or not.
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:820, in Module._apply(self, fn)
#     816 # Tensors stored in modules are graph leaves, and we don't want to
#     817 # track autograd history of `param_applied`, so we have to use
#     818 # `with torch.no_grad():`
#     819 with torch.no_grad():
# --> 820     param_applied = fn(param)
#     821 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     822 if should_use_set_data:
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1143, in Module.to.<locals>.convert(t)
#    1140 if convert_to_format is not None and t.dim() in (4, 5):
#    1141     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1142                 non_blocking, memory_format=convert_to_format)
# -> 1143 return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/cuda/__init__.py:247, in _lazy_init()
#     245 if 'CUDA_MODULE_LOADING' not in os.environ:
#     246     os.environ['CUDA_MODULE_LOADING'] = 'LAZY'
# --> 247 torch._C._cuda_init()
#     248 # Some of the queued calls may reentrantly call _lazy_init();
#     249 # we need to just return without initializing in that case.
#     250 # However, we must not let any *other* threads in!
#     251 _tls.is_initializing = True
#
# RuntimeError: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero.

# %%
inf_out = pl.cur_clf.predict(dm.ds_std_test,conf['inference_conf'])
bin_data = compute_calibration(dm.ds_std_test.Y, inf_out['labels'], inf_out['confidence'], num_bins=20)
ax = plt.subplot()
reliability_diagram_subplot(ax, bin_data, draw_ece=True, draw_bin_importance=False, title="Reliability Diagram",  xlabel="Confidence", ylabel="Expected Accuracy",disable_labels=False)

# %%
lenet_clf_model = pl.cur_clf.model
test_ds = dm.ds_std_test

inference_conf = {} 
inference_conf['device']= 'cpu'
inf_out_test_1 = pl.cur_clf.predict(test_ds, inference_conf) 

inf_out_test_1['true_labels'] = test_ds.Y
c_idx = inf_out_test_1['true_labels'] ==  inf_out_test_1['labels']
i_idx =inf_out_test_1['true_labels'] !=  inf_out_test_1['labels']


sns.kdeplot(inf_out_test_1['confidence'][c_idx])
sns.kdeplot(inf_out_test_1['confidence'][i_idx])

#plt.hist(inf_out_val_1['confidence'][c_idx])
#plt.hist(inf_out_val_1['confidence'][i_idx])
# Out:
# <Axes: ylabel='Density'>

# %%
dm.unmark_auto_labeled()

auto_labeler = AutoLabeling(conf,dm,pl.cur_clf,logger)
out = auto_labeler.run()
out = dm.get_auto_labeling_counts()
print(out)
# Out:
# [09/16/2023 11:20:23 AM : INFO  : auto_label : ] : ========================= Begin Auto-Labeling selective ==========================
# [09/16/2023 11:20:23 AM : DEBUG : auto_label : ] : Auto Labeling Conf : {'method_name': 'selective', 'score_type': 'confidence', 'class_wise': 'independent', 'auto_label_err_threshold': 0.05, 'C_1': 0, 'ucb': 'sigma', 'fast': True}
# [09/16/2023 11:20:23 AM : INFO  : auto_label : ] : Number of unlabeled points : 41950
# [09/16/2023 11:20:24 AM : INFO  : auto_label : ] : Using number of validation points : 5000
# [09/16/2023 11:20:24 AM : INFO  : auto_label : ] : Using Auto-Labeling Error Threshold = 0.05
# [09/16/2023 11:20:24 AM : DEBUG : auto_label : ] : Expected Calibration Error on Validation set : 0.0992879299759865
# [09/16/2023 11:20:24 AM : INFO  : auto_label : ] : Determining Thresholds : Class Wise : independent
# [09/16/2023 11:20:24 AM : DEBUG : threshold_ : ] : C_1 = 0 UCB = sigma
# [09/16/2023 11:20:24 AM : INFO  : threshold_ : ] : auto-labeling threshold t_i=0.4977838695049286 for class 0
# [09/16/2023 11:20:24 AM : INFO  : threshold_ : ] : auto-labeling threshold t_i=0.9796776175498962 for class 1
# [09/16/2023 11:20:24 AM : INFO  : threshold_ : ] : auto-labeling threshold t_i=0.6188510060310364 for class 2
# [09/16/2023 11:20:24 AM : INFO  : threshold_ : ] : auto-labeling threshold t_i=0.6693820953369141 for class 3
# [09/16/2023 11:20:24 AM : INFO  : threshold_ : ] : auto-labeling threshold t_i=0.8049383759498596 for class 4
# [09/16/2023 11:20:24 AM : INFO  : threshold_ : ] : auto-labeling threshold t_i=0.9633660316467285 for class 5
# [09/16/2023 11:20:25 AM : INFO  : threshold_ : ] : auto-labeling threshold t_i=0.7205004692077637 for class 6
# [09/16/2023 11:20:25 AM : INFO  : threshold_ : ] : auto-labeling threshold t_i=0.6865566968917847 for class 7
# [09/16/2023 11:20:25 AM : INFO  : threshold_ : ] : auto-labeling threshold t_i=0.8211601376533508 for class 8
# [09/16/2023 11:20:25 AM : INFO  : threshold_ : ] : auto-labeling threshold t_i=0.9474475979804993 for class 9
# [09/16/2023 11:20:25 AM : INFO  : auto_label : ] : auto-labeling thresholds from val set: [0.49778387, 0.9796776, 0.618851, 0.6693821, 0.8049384, 0.96336603, 0.72050047, 0.6865567, 0.82116014, 0.9474476]
# [09/16/2023 11:20:26 AM : INFO  : auto_label : ] : Num auto labeled points : 13376
# [09/16/2023 11:20:26 AM : INFO  : auto_label : ] : Num validation pts to remove : 1610
# [09/16/2023 11:20:26 AM : INFO  : auto_label : ] : ============================== Done Auto-Labeling ==============================
# {'auto_labeled_acc': 0.9404904306220095, 'coverage_1': 0.31847619047619047, 'coverage_2': 0}
